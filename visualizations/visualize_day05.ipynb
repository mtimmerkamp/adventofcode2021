# %%
# %pylab inline

import PIL.Image
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
for filename in ['out_05.1.txt', 'out_05.2.txt']:
    with open(filename) as f:
        lines = f.readlines()

        array = empty((len(lines[0]), len(lines)), dtype=float)
        for y, line in enumerate(lines):
            for x, char in enumerate(line.strip()):
                if char == '.':
                    array[x, y] = 0
                else:
                    array[x, y] = int(char)
        
        array = array / np.max(array) * 255

        image = PIL.Image.fromarray(array).convert('L')
        image.save(filename + '.png')

# %%
image
# Out:
# <PIL.Image.Image image mode=L size=980x982 at 0x7F055F783A00>
